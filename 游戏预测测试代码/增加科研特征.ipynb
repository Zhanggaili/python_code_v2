# %%
import pandas as pd

#data_top_sr = pd.read_csv("under_sample_data.csv")
data_train = pd.read_csv("tap_fun_train.csv")
data_top_sr = data_train[(data_train['sr_troop_attack_level']>0) | 
                         (data_train['sr_rss_c_gather_level']>0) |
                         (data_train['sr_rss_c_prod_level']>0) |
                         (data_train['sr_rss_c_gather_level']>0) |
                         (data_train['sr_guest_troop_capacity_level']>0) |
                         (data_train['sr_march_size_level']>0) |
                         (data_train['sr_rss_help_bonus_level']>0) 
                        ]
data_top_sr.to_csv("top_sr.csv",index=None)
print data_top_sr.columns,data_top_sr.index

# %%
import pandas as pd
data_train = pd.read_csv("tap_fun_train.csv")
data_top_sr = data_train[
                         (data_train['sr_rss_help_bonus_level']>0) 
                        ]
data_top_sr.to_csv("sr_rss_help_bonus_level.csv",index=None)
print data_top_sr.columns,data_top_sr.index
# Out:
# Index([u'user_id', u'register_time', u'wood_add_value', u'wood_reduce_value',
#        u'stone_add_value', u'stone_reduce_value', u'ivory_add_value',
#        u'ivory_reduce_value', u'meat_add_value', u'meat_reduce_value',
#        ...
#        u'pvp_battle_count', u'pvp_lanch_count', u'pvp_win_count',
#        u'pve_battle_count', u'pve_lanch_count', u'pve_win_count',
#        u'avg_online_minutes', u'pay_price', u'pay_count',
#        u'prediction_pay_price'],
#       dtype='object', length=109) Int64Index([1423324, 1520367, 1831948], dtype='int64')

# %%
import pandas as pd

data_train = pd.read_csv("under_sample_data.csv")
data_train['stronghold_upgradetime'] = 2**(data_train['bd_stronghold_level'])-1
data_train['dolmen_upgradetime'] = 2**(data_train['bd_dolmen_level'])-1
data_train['pvp_win_rate'] = 100*data_train['pvp_win_count']/data_train['pvp_battle_count']
data_train['pve_win_rate'] = 100*data_train['pve_win_count']/data_train['pve_battle_count']

#部队战力科研等级
data_train['sr_scout_level'] = 2**(data_train['sr_scout_level'])- 1
data_train['sr_training_speed_level']= 2*(2**(data_train['sr_training_speed_level'])- 1)
data_train['sr_infantry_tier_2_level']= 3*(2**(data_train['sr_infantry_tier_2_level'])- 1)
data_train['sr_cavalry_tier_2_level']= 3*(2**(data_train['sr_cavalry_tier_2_level'])- 1)
data_train['sr_shaman_tier_2_level']= 3*(2**(data_train['sr_shaman_tier_2_level'])- 1)
data_train['sr_infantry_atk_level']= 4*(2**(data_train['sr_infantry_atk_level'])- 1)
data_train['sr_cavalry_atk_level']= 4*(2**(data_train['sr_cavalry_atk_level'])- 1)
data_train['sr_shaman_atk_level']= 4*(2**(data_train['sr_shaman_atk_level'])- 1)
data_train['sr_infantry_tier_3_level']= 5*(2**(data_train['sr_infantry_tier_3_level'])- 1)
data_train['sr_cavalry_tier_3_level']= 5*(2**(data_train['sr_cavalry_tier_3_level'])- 1)
data_train['sr_shaman_tier_3_level']= 5*(2**(data_train['sr_shaman_tier_3_level'])- 1)
data_train['sr_troop_defense_level']= 6*(2**(data_train['sr_troop_defense_level'])- 1)
data_train['sr_infantry_def_level']= 7*(2**(data_train['sr_infantry_def_level'])- 1)
data_train['sr_cavalry_def_level']= 7*(2**(data_train['sr_cavalry_def_level'])- 1)
data_train['sr_shaman_def_level']= 7*(2**(data_train['sr_shaman_def_level'])- 1)
data_train['sr_infantry_hp_level']= 8*(2**(data_train['sr_infantry_hp_level'])- 1)
data_train['sr_cavalry_hp_level']= 8*(2**(data_train['sr_cavalry_hp_level'])- 1)
data_train['sr_shaman_hp_level']= 8*(2**(data_train['sr_shaman_hp_level'])- 1)
data_train['sr_infantry_tier_4_level']= 9*(2**(data_train['sr_infantry_tier_4_level'])- 1)
data_train['sr_cavalry_tier_4_level']= 9*(2**(data_train['sr_cavalry_tier_4_level'])- 1)
data_train['sr_shaman_tier_4_level']= 9*(2**(data_train['sr_shaman_tier_4_level'])- 1)
data_train['sr_troop_attack_level']= 9*(2**(data_train['sr_troop_attack_level'])- 1)

#资源科研等级
data_train['sr_construction_speed_level'] = 2**(data_train['sr_construction_speed_level'])- 1
data_train['sr_hide_storage_level']= 2*(2**(data_train['sr_hide_storage_level'])- 1)
data_train['sr_troop_consumption_level']= 2*(2**(data_train['sr_troop_consumption_level'])- 1)
data_train['sr_rss_a_prod_levell']= 3*(2**(data_train['sr_rss_a_prod_levell'])- 1)
data_train['sr_rss_b_prod_level']= 6*(2**(data_train['sr_rss_b_prod_level'])- 1)
data_train['sr_rss_c_prod_level']= 7*(2**(data_train['sr_rss_c_prod_level'])- 1)
data_train['sr_rss_d_prod_level']= 2*(2**(data_train['sr_rss_d_prod_level'])- 1)
data_train['sr_rss_a_gather_level']= 3*(2**(data_train['sr_rss_a_gather_level'])- 1)
data_train['sr_rss_b_gather_level']= 6*(2**(data_train['sr_rss_b_gather_level'])- 1)
data_train['sr_rss_c_gather_level']= 7*(2**(data_train['sr_rss_c_gather_level'])- 1)
data_train['sr_rss_d_gather_level']= 3*(2**(data_train['sr_rss_d_gather_level'])- 1)
data_train['sr_troop_load_level']= 4*(2**(data_train['sr_troop_load_level'])- 1)
data_train['sr_rss_e_gather_level']= 6*(2**(data_train['sr_rss_e_gather_level'])- 1)
data_train['sr_rss_e_prod_level']= 5*(2**(data_train['sr_rss_e_prod_level'])- 1)

#据点科研等级
data_train['sr_outpost_durability_level'] = 2**(data_train['sr_outpost_durability_level'])- 1
data_train['sr_outpost_tier_2_level']= 2*(2**(data_train['sr_outpost_tier_2_level'])- 1)
data_train['sr_healing_space_level']= 3*(2**(data_train['sr_healing_space_level'])- 1)
data_train['sr_gathering_hunter_buff_level']= 3*(2**(data_train['sr_gathering_hunter_buff_level'])- 1)
data_train['sr_healing_speed_level']= 3*(2**(data_train['sr_healing_speed_level'])- 1)
data_train['sr_outpost_tier_3_level']= 4*(2**(data_train['sr_outpost_tier_3_level'])- 1)
data_train['sr_alliance_march_speed_level']= 5*(2**(data_train['sr_alliance_march_speed_level'])- 1)
data_train['sr_pvp_march_speed_level']= 5*(2**(data_train['sr_pvp_march_speed_level'])- 1)
data_train['sr_gathering_march_speed_level']= 5*(2**(data_train['sr_gathering_march_speed_level'])- 1)
data_train['sr_outpost_tier_4_level']= 6*(2**(data_train['sr_outpost_tier_4_level'])- 1)
data_train['sr_guest_troop_capacity_level']= 7*(2**(data_train['sr_guest_troop_capacity_level'])- 1)
data_train['sr_march_size_level']= 7*(2**(data_train['sr_march_size_level'])- 1)
data_train['sr_rss_help_bonus_level']= 7*(2**(data_train['sr_rss_help_bonus_level'])- 1)

data_train['prediction_pay_price_2'] = data_train['prediction_pay_price']
del data_train['prediction_pay_price']
data_train.rename(columns={'prediction_pay_price_2':'prediction_pay_price'}, inplace = True)

print data_train.columns
data_train.to_csv("under_sample_data_weight.csv",index=None)
# Out:
# Index([u'user_id', u'register_time', u'wood_add_value', u'wood_reduce_value',
#        u'stone_add_value', u'stone_reduce_value', u'ivory_add_value',
#        u'ivory_reduce_value', u'meat_add_value', u'meat_reduce_value',
#        ...
#        u'pve_lanch_count', u'pve_win_count', u'avg_online_minutes',
#        u'pay_price', u'pay_count', u'stronghold_upgradetime',
#        u'dolmen_upgradetime', u'pvp_win_rate', u'pve_win_rate',
#        u'prediction_pay_price'],
#       dtype='object', length=113)

# %%
# import pandas as pd

# data_train = pd.read_csv("under_sample_data_weight.csv")
# #资源科研等级
# data_train['sr_construction_speed_level'] = 2**(data_train['sr_construction_speed_level'])- 1
# data_train['sr_hide_storage_level']= 2*(2**(data_train['sr_hide_storage_level'])- 1)
# data_train['sr_troop_consumption_level']= 2*(2**(data_train['sr_troop_consumption_level'])- 1)
# data_train['sr_rss_a_prod_levell']= 3*(2**(data_train['sr_rss_a_prod_levell'])- 1)
# data_train['sr_rss_b_prod_level']= 6*(2**(data_train['sr_rss_b_prod_level'])- 1)
# data_train['sr_rss_c_prod_level']= 7*(2**(data_train['sr_rss_c_prod_level'])- 1)
# data_train['sr_rss_d_prod_level']= 2*(2**(data_train['sr_rss_d_prod_level'])- 1)
# data_train['sr_rss_a_gather_level']= 3*(2**(data_train['sr_rss_a_gather_level'])- 1)
# data_train['sr_rss_b_gather_level']= 6*(2**(data_train['sr_rss_b_gather_level'])- 1)
# data_train['sr_rss_c_gather_level']= 7*(2**(data_train['sr_rss_c_gather_level'])- 1)
# data_train['sr_rss_d_gather_level']= 3*(2**(data_train['sr_rss_d_gather_level'])- 1)
# data_train['sr_troop_load_level']= 4*(2**(data_train['sr_troop_load_level'])- 1)
# data_train['sr_rss_e_gather_level']= 6*(2**(data_train['sr_rss_e_gather_level'])- 1)
# data_train['sr_rss_e_prod_level']= 5*(2**(data_train['sr_rss_e_prod_level'])- 1)

# data_train['prediction_pay_price_2'] = data_train['prediction_pay_price']
# del data_train['prediction_pay_price']
# data_train.rename(columns={'prediction_pay_price_2':'prediction_pay_price'}, inplace = True)

# print data_train.columns
# data_train.to_csv("under_sample_data_weight_v2.csv",index=None)
# Out:
# Index([u'user_id', u'register_time', u'wood_add_value', u'wood_reduce_value',
#        u'stone_add_value', u'stone_reduce_value', u'ivory_add_value',
#        u'ivory_reduce_value', u'meat_add_value', u'meat_reduce_value',
#        ...
#        u'pve_lanch_count', u'pve_win_count', u'avg_online_minutes',
#        u'pay_price', u'pay_count', u'stronghold_upgradetime',
#        u'dolmen_upgradetime', u'pvp_win_rate', u'pve_win_rate',
#        u'prediction_pay_price'],
#       dtype='object', length=113)

# %%
# import pandas as pd

# data_train = pd.read_csv("under_sample_data_weight_v2.csv")
# #据点科研等级
# data_train['sr_outpost_durability_level'] = 2**(data_train['sr_outpost_durability_level'])- 1
# data_train['sr_outpost_tier_2_level']= 2*(2**(data_train['sr_outpost_tier_2_level'])- 1)
# data_train['sr_healing_space_level']= 3*(2**(data_train['sr_healing_space_level'])- 1)
# data_train['sr_gathering_hunter_buff_level']= 3*(2**(data_train['sr_gathering_hunter_buff_level'])- 1)
# data_train['sr_healing_speed_level']= 3*(2**(data_train['sr_healing_speed_level'])- 1)
# data_train['sr_outpost_tier_3_level']= 4*(2**(data_train['sr_outpost_tier_3_level'])- 1)
# data_train['sr_alliance_march_speed_level']= 5*(2**(data_train['sr_alliance_march_speed_level'])- 1)
# data_train['sr_pvp_march_speed_level']= 5*(2**(data_train['sr_pvp_march_speed_level'])- 1)
# data_train['sr_gathering_march_speed_level']= 5*(2**(data_train['sr_gathering_march_speed_level'])- 1)
# data_train['sr_outpost_tier_4_level']= 6*(2**(data_train['sr_outpost_tier_4_level'])- 1)
# data_train['sr_guest_troop_capacity_level']= 7*(2**(data_train['sr_guest_troop_capacity_level'])- 1)
# data_train['sr_march_size_level']= 7*(2**(data_train['sr_march_size_level'])- 1)
# data_train['sr_rss_help_bonus_level']= 7*(2**(data_train['sr_rss_help_bonus_level'])- 1)

# data_train['prediction_pay_price_2'] = data_train['prediction_pay_price']
# del data_train['prediction_pay_price']
# data_train.rename(columns={'prediction_pay_price_2':'prediction_pay_price'}, inplace = True)

# print data_train.columns
# data_train.to_csv("under_sample_data_weight_v3.csv",index=None)
# Out:
# Index([u'user_id', u'register_time', u'wood_add_value', u'wood_reduce_value',
#        u'stone_add_value', u'stone_reduce_value', u'ivory_add_value',
#        u'ivory_reduce_value', u'meat_add_value', u'meat_reduce_value',
#        ...
#        u'pve_lanch_count', u'pve_win_count', u'avg_online_minutes',
#        u'pay_price', u'pay_count', u'stronghold_upgradetime',
#        u'dolmen_upgradetime', u'pvp_win_rate', u'pve_win_rate',
#        u'prediction_pay_price'],
#       dtype='object', length=113)

# %%
import pandas as pd

data_train = pd.read_csv("tap_fun_train.csv")

data_train['stronghold_upgradetime'] = 2**(data_train['bd_stronghold_level'])- 1
data_train['dolmen_upgradetime'] = 2**(data_train['bd_dolmen_level'])- 1
data_train['pvp_win_rate'] = 100*data_train['pvp_win_count']/data_train['pvp_battle_count']
data_train['pve_win_rate'] = 100*data_train['pve_win_count']/data_train['pve_battle_count']

#部队战力科研等级
data_train['sr_scout_level'] = 2**(data_train['sr_scout_level'])- 1
data_train['sr_training_speed_level']= 2*(2**(data_train['sr_training_speed_level'])- 1)
data_train['sr_infantry_tier_2_level']= 3*(2**(data_train['sr_infantry_tier_2_level'])- 1)
data_train['sr_cavalry_tier_2_level']= 3*(2**(data_train['sr_cavalry_tier_2_level'])- 1)
data_train['sr_shaman_tier_2_level']= 3*(2**(data_train['sr_shaman_tier_2_level'])- 1)
data_train['sr_infantry_atk_level']= 4*(2**(data_train['sr_infantry_atk_level'])- 1)
data_train['sr_cavalry_atk_level']= 4*(2**(data_train['sr_cavalry_atk_level'])- 1)
data_train['sr_shaman_atk_level']= 4*(2**(data_train['sr_shaman_atk_level'])- 1)
data_train['sr_infantry_tier_3_level']= 5*(2**(data_train['sr_infantry_tier_3_level'])- 1)
data_train['sr_cavalry_tier_3_level']= 5*(2**(data_train['sr_cavalry_tier_3_level'])- 1)
data_train['sr_shaman_tier_3_level']= 5*(2**(data_train['sr_shaman_tier_3_level'])- 1)
data_train['sr_troop_defense_level']= 6*(2**(data_train['sr_troop_defense_level'])- 1)
data_train['sr_infantry_def_level']= 7*(2**(data_train['sr_infantry_def_level'])- 1)
data_train['sr_cavalry_def_level']= 7*(2**(data_train['sr_cavalry_def_level'])- 1)
data_train['sr_shaman_def_level']= 7*(2**(data_train['sr_shaman_def_level'])- 1)
data_train['sr_infantry_hp_level']= 8*(2**(data_train['sr_infantry_hp_level'])- 1)
data_train['sr_cavalry_hp_level']= 8*(2**(data_train['sr_cavalry_hp_level'])- 1)
data_train['sr_shaman_hp_level']= 8*(2**(data_train['sr_shaman_hp_level'])- 1)
data_train['sr_infantry_tier_4_level']= 9*(2**(data_train['sr_infantry_tier_4_level'])- 1)
data_train['sr_cavalry_tier_4_level']= 9*(2**(data_train['sr_cavalry_tier_4_level'])- 1)
data_train['sr_shaman_tier_4_level']= 9*(2**(data_train['sr_shaman_tier_4_level'])- 1)
data_train['sr_troop_attack_level']= 9*(2**(data_train['sr_troop_attack_level'])- 1)

#据点科研等级
data_train['sr_outpost_durability_level'] = 2**(data_train['sr_outpost_durability_level'])- 1
data_train['sr_outpost_tier_2_level']= 2*(2**(data_train['sr_outpost_tier_2_level'])- 1)
data_train['sr_healing_space_level']= 3*(2**(data_train['sr_healing_space_level'])- 1)
data_train['sr_gathering_hunter_buff_level']= 3*(2**(data_train['sr_gathering_hunter_buff_level'])- 1)
data_train['sr_healing_speed_level']= 3*(2**(data_train['sr_healing_speed_level'])- 1)
data_train['sr_outpost_tier_3_level']= 4*(2**(data_train['sr_outpost_tier_3_level'])- 1)
data_train['sr_alliance_march_speed_level']= 5*(2**(data_train['sr_alliance_march_speed_level'])- 1)
data_train['sr_pvp_march_speed_level']= 5*(2**(data_train['sr_pvp_march_speed_level'])- 1)
data_train['sr_gathering_march_speed_level']= 5*(2**(data_train['sr_gathering_march_speed_level'])- 1)
data_train['sr_outpost_tier_4_level']= 6*(2**(data_train['sr_outpost_tier_4_level'])- 1)
data_train['sr_guest_troop_capacity_level']= 7*(2**(data_train['sr_guest_troop_capacity_level'])- 1)
data_train['sr_march_size_level']= 7*(2**(data_train['sr_march_size_level'])- 1)
data_train['sr_rss_help_bonus_level']= 7*(2**(data_train['sr_rss_help_bonus_level'])- 1)

#资源科研等级
data_train['sr_construction_speed_level'] = 2**(data_train['sr_construction_speed_level'])- 1
data_train['sr_hide_storage_level']= 2*(2**(data_train['sr_hide_storage_level'])- 1)
data_train['sr_troop_consumption_level']= 2*(2**(data_train['sr_troop_consumption_level'])- 1)
data_train['sr_rss_a_prod_levell']= 3*(2**(data_train['sr_rss_a_prod_levell'])- 1)
data_train['sr_rss_b_prod_level']= 6*(2**(data_train['sr_rss_b_prod_level'])- 1)
data_train['sr_rss_c_prod_level']= 7*(2**(data_train['sr_rss_c_prod_level'])- 1)
data_train['sr_rss_d_prod_level']= 2*(2**(data_train['sr_rss_d_prod_level'])- 1)
data_train['sr_rss_a_gather_level']= 3*(2**(data_train['sr_rss_a_gather_level'])- 1)
data_train['sr_rss_b_gather_level']= 6*(2**(data_train['sr_rss_b_gather_level'])- 1)
data_train['sr_rss_c_gather_level']= 7*(2**(data_train['sr_rss_c_gather_level'])- 1)
data_train['sr_rss_d_gather_level']= 3*(2**(data_train['sr_rss_d_gather_level'])- 1)
data_train['sr_troop_load_level']= 4*(2**(data_train['sr_troop_load_level'])- 1)
data_train['sr_rss_e_gather_level']= 6*(2**(data_train['sr_rss_e_gather_level'])- 1)
data_train['sr_rss_e_prod_level']= 5*(2**(data_train['sr_rss_e_prod_level'])- 1)

data_train['prediction_pay_price_2'] = data_train['prediction_pay_price']
del data_train['prediction_pay_price']
data_train.rename(columns={'prediction_pay_price_2':'prediction_pay_price'}, inplace = True)

print data_train.columns
data_train.to_csv("tap_fun_train_weight.csv",index=None)
# Out:
# Index([u'user_id', u'register_time', u'wood_add_value', u'wood_reduce_value',
#        u'stone_add_value', u'stone_reduce_value', u'ivory_add_value',
#        u'ivory_reduce_value', u'meat_add_value', u'meat_reduce_value',
#        ...
#        u'pve_lanch_count', u'pve_win_count', u'avg_online_minutes',
#        u'pay_price', u'pay_count', u'stronghold_upgradetime',
#        u'dolmen_upgradetime', u'pvp_win_rate', u'pve_win_rate',
#        u'prediction_pay_price'],
#       dtype='object', length=113)

# %%
# import pandas as pd

# data_train = pd.read_csv("tap_fun_train_weight.csv")
# #资源科研等级
# data_train['sr_construction_speed_level'] = 2**(data_train['sr_construction_speed_level'])- 1
# data_train['sr_hide_storage_level']= 2*(2**(data_train['sr_hide_storage_level'])- 1)
# data_train['sr_troop_consumption_level']= 2*(2**(data_train['sr_troop_consumption_level'])- 1)
# data_train['sr_rss_a_prod_levell']= 3*(2**(data_train['sr_rss_a_prod_levell'])- 1)
# data_train['sr_rss_b_prod_level']= 6*(2**(data_train['sr_rss_b_prod_level'])- 1)
# data_train['sr_rss_c_prod_level']= 7*(2**(data_train['sr_rss_c_prod_level'])- 1)
# data_train['sr_rss_d_prod_level']= 2*(2**(data_train['sr_rss_d_prod_level'])- 1)
# data_train['sr_rss_a_gather_level']= 3*(2**(data_train['sr_rss_a_gather_level'])- 1)
# data_train['sr_rss_b_gather_level']= 6*(2**(data_train['sr_rss_b_gather_level'])- 1)
# data_train['sr_rss_c_gather_level']= 7*(2**(data_train['sr_rss_c_gather_level'])- 1)
# data_train['sr_rss_d_gather_level']= 3*(2**(data_train['sr_rss_d_gather_level'])- 1)
# data_train['sr_troop_load_level']= 4*(2**(data_train['sr_troop_load_level'])- 1)
# data_train['sr_rss_e_gather_level']= 6*(2**(data_train['sr_rss_e_gather_level'])- 1)
# data_train['sr_rss_e_prod_level']= 5*(2**(data_train['sr_rss_e_prod_level'])- 1)

# data_train['prediction_pay_price_2'] = data_train['prediction_pay_price']
# del data_train['prediction_pay_price']
# data_train.rename(columns={'prediction_pay_price_2':'prediction_pay_price'}, inplace = True)

# print data_train.columns
# data_train.to_csv("tap_fun_train_weight_v2.csv",index=None)
# Out:
# Index([u'user_id', u'register_time', u'wood_add_value', u'wood_reduce_value',
#        u'stone_add_value', u'stone_reduce_value', u'ivory_add_value',
#        u'ivory_reduce_value', u'meat_add_value', u'meat_reduce_value',
#        ...
#        u'pve_lanch_count', u'pve_win_count', u'avg_online_minutes',
#        u'pay_price', u'pay_count', u'stronghold_upgradetime',
#        u'dolmen_upgradetime', u'pvp_win_rate', u'pve_win_rate',
#        u'prediction_pay_price'],
#       dtype='object', length=113)

# %%
import pandas as pd

data_train = pd.read_csv("tap_fun_train_weight_v2.csv")
#据点科研等级
data_train['sr_outpost_durability_level'] = 2**(data_train['sr_outpost_durability_level'])- 1
data_train['sr_outpost_tier_2_level']= 2*(2**(data_train['sr_outpost_tier_2_level'])- 1)
data_train['sr_healing_space_level']= 3*(2**(data_train['sr_healing_space_level'])- 1)
data_train['sr_gathering_hunter_buff_level']= 3*(2**(data_train['sr_gathering_hunter_buff_level'])- 1)
data_train['sr_healing_speed_level']= 3*(2**(data_train['sr_healing_speed_level'])- 1)
data_train['sr_outpost_tier_3_level']= 4*(2**(data_train['sr_outpost_tier_3_level'])- 1)
data_train['sr_alliance_march_speed_level']= 5*(2**(data_train['sr_alliance_march_speed_level'])- 1)
data_train['sr_pvp_march_speed_level']= 5*(2**(data_train['sr_pvp_march_speed_level'])- 1)
data_train['sr_gathering_march_speed_level']= 5*(2**(data_train['sr_gathering_march_speed_level'])- 1)
data_train['sr_outpost_tier_4_level']= 6*(2**(data_train['sr_outpost_tier_4_level'])- 1)
data_train['sr_guest_troop_capacity_level']= 7*(2**(data_train['sr_guest_troop_capacity_level'])- 1)
data_train['sr_march_size_level']= 7*(2**(data_train['sr_march_size_level'])- 1)
data_train['sr_rss_help_bonus_level']= 7*(2**(data_train['sr_rss_help_bonus_level'])- 1)

data_train['prediction_pay_price_2'] = data_train['prediction_pay_price']
del data_train['prediction_pay_price']
data_train.rename(columns={'prediction_pay_price_2':'prediction_pay_price'}, inplace = True)

print data_train.columns
data_train.to_csv("tap_fun_train_weight_v3.csv",index=None)
# Out:
# Index([u'user_id', u'register_time', u'wood_add_value', u'wood_reduce_value',
#        u'stone_add_value', u'stone_reduce_value', u'ivory_add_value',
#        u'ivory_reduce_value', u'meat_add_value', u'meat_reduce_value',
#        ...
#        u'pve_lanch_count', u'pve_win_count', u'avg_online_minutes',
#        u'pay_price', u'pay_count', u'stronghold_upgradetime',
#        u'dolmen_upgradetime', u'pvp_win_rate', u'pve_win_rate',
#        u'prediction_pay_price'],
#       dtype='object', length=113)

# %%
import pandas as pd

data_train = pd.read_csv('tap_fun_test.csv')
data_train['stronghold_upgradetime'] = 2**(data_train['bd_stronghold_level'])-1
data_train['dolmen_upgradetime'] = 2**(data_train['bd_dolmen_level'])-1
data_train['pvp_win_rate'] = 100*data_train['pvp_win_count']/data_train['pvp_battle_count']
data_train['pve_win_rate'] = 100*data_train['pve_win_count']/data_train['pve_battle_count']

#部队战力科研等级
data_train['sr1_scout_level'] = 2**(data_train['sr_scout_level'])- 1
data_train['sr1_training_speed_level']= 2*(2**(data_train['sr_training_speed_level'])- 1)
data_train['sr1_infantry_tier_2_level']= 3*(2**(data_train['sr_infantry_tier_2_level'])- 1)
data_train['sr1_cavalry_tier_2_level']= 3*(2**(data_train['sr_cavalry_tier_2_level'])- 1)
data_train['sr1_shaman_tier_2_level']= 3*(2**(data_train['sr_shaman_tier_2_level'])- 1)
data_train['sr1_infantry_atk_level']= 4*(2**(data_train['sr_infantry_atk_level'])- 1)
data_train['sr1_cavalry_atk_level']= 4*(2**(data_train['sr_cavalry_atk_level'])- 1)
data_train['sr1_shaman_atk_level']= 4*(2**(data_train['sr_shaman_atk_level'])- 1)
data_train['sr1_infantry_tier_3_level']= 5*(2**(data_train['sr_infantry_tier_3_level'])- 1)
data_train['sr1_cavalry_tier_3_level']= 5*(2**(data_train['sr_cavalry_tier_3_level'])- 1)
data_train['sr1_shaman_tier_3_level']= 5*(2**(data_train['sr_shaman_tier_3_level'])- 1)
data_train['sr1_troop_defense_level']= 6*(2**(data_train['sr_troop_defense_level'])- 1)
data_train['sr1_infantry_def_level']= 7*(2**(data_train['sr_infantry_def_level'])- 1)
data_train['sr1_cavalry_def_level']= 7*(2**(data_train['sr_cavalry_def_level'])- 1)
data_train['sr1_shaman_def_level']= 7*(2**(data_train['sr_shaman_def_level'])- 1)
data_train['sr1_infantry_hp_level']= 8*(2**(data_train['sr_infantry_hp_level'])- 1)
data_train['sr1_cavalry_hp_level']= 8*(2**(data_train['sr_cavalry_hp_level'])- 1)
data_train['sr1_shaman_hp_level']= 8*(2**(data_train['sr_shaman_hp_level'])- 1)
data_train['sr1_infantry_tier_4_level']= 9*(2**(data_train['sr_infantry_tier_4_level'])- 1)
data_train['sr1_cavalry_tier_4_level']= 9*(2**(data_train['sr_cavalry_tier_4_level'])- 1)
data_train['sr1_shaman_tier_4_level']= 9*(2**(data_train['sr_shaman_tier_4_level'])- 1)
data_train['sr1_troop_attack_level']= 9*(2**(data_train['sr_troop_attack_level'])- 1)
#资源科研等级
data_train['sr1_construction_speed_level'] = 2**(data_train['sr_construction_speed_level'])- 1
data_train['sr1_hide_storage_level']= 2*(2**(data_train['sr_hide_storage_level'])- 1)
data_train['sr1_troop_consumption_level']= 2*(2**(data_train['sr_troop_consumption_level'])- 1)
data_train['sr1_rss_a_prod_levell']= 3*(2**(data_train['sr_rss_a_prod_levell'])- 1)
data_train['sr1_rss_b_prod_level']= 6*(2**(data_train['sr_rss_b_prod_level'])- 1)
data_train['sr1_rss_c_prod_level']= 7*(2**(data_train['sr_rss_c_prod_level'])- 1)
data_train['sr1_rss_d_prod_level']= 2*(2**(data_train['sr_rss_d_prod_level'])- 1)
data_train['sr1_rss_a_gather_level']= 3*(2**(data_train['sr_rss_a_gather_level'])- 1)
data_train['sr1_rss_b_gather_level']= 6*(2**(data_train['sr_rss_b_gather_level'])- 1)
data_train['sr1_rss_c_gather_level']= 7*(2**(data_train['sr_rss_c_gather_level'])- 1)
data_train['sr1_rss_d_gather_level']= 3*(2**(data_train['sr_rss_d_gather_level'])- 1)
data_train['sr1_troop_load_level']= 4*(2**(data_train['sr_troop_load_level'])- 1)
data_train['sr1_rss_e_gather_level']= 6*(2**(data_train['sr_rss_e_gather_level'])- 1)
data_train['sr1_rss_e_prod_level']= 5*(2**(data_train['sr_rss_e_prod_level'])- 1)
#据点科研等级
data_train['sr1_outpost_durability_level'] = 2**(data_train['sr_outpost_durability_level'])- 1
data_train['sr1_outpost_tier_2_level']= 2*(2**(data_train['sr_outpost_tier_2_level'])- 1)
data_train['sr1_healing_space_level']= 3*(2**(data_train['sr_healing_space_level'])- 1)
data_train['sr1_gathering_hunter_buff_level']= 3*(2**(data_train['sr_gathering_hunter_buff_level'])- 1)
data_train['sr1_healing_speed_level']= 3*(2**(data_train['sr_healing_speed_level'])- 1)
data_train['sr1_outpost_tier_3_level']= 4*(2**(data_train['sr_outpost_tier_3_level'])- 1)
data_train['sr1_alliance_march_speed_level']= 5*(2**(data_train['sr_alliance_march_speed_level'])- 1)
data_train['sr1_pvp_march_speed_level']= 5*(2**(data_train['sr_pvp_march_speed_level'])- 1)
data_train['sr1_gathering_march_speed_level']= 5*(2**(data_train['sr_gathering_march_speed_level'])- 1)
data_train['sr1_outpost_tier_4_level']= 6*(2**(data_train['sr_outpost_tier_4_level'])- 1)
data_train['sr1_guest_troop_capacity_level']= 7*(2**(data_train['sr_guest_troop_capacity_level'])- 1)
data_train['sr1_march_size_level']= 7*(2**(data_train['sr_march_size_level'])- 1)
data_train['sr1_rss_help_bonus_level']= 7*(2**(data_train['sr_rss_help_bonus_level'])- 1)

print data_train.columns
data_train.to_csv("tap_fun_test_weight.csv",index=None)
# Out:
# Index([u'user_id', u'register_time', u'wood_add_value', u'wood_reduce_value',
#        u'stone_add_value', u'stone_reduce_value', u'ivory_add_value',
#        u'ivory_reduce_value', u'meat_add_value', u'meat_reduce_value',
#        ...
#        u'sr1_gathering_hunter_buff_level', u'sr1_healing_speed_level',
#        u'sr1_outpost_tier_3_level', u'sr1_alliance_march_speed_level',
#        u'sr1_pvp_march_speed_level', u'sr1_gathering_march_speed_level',
#        u'sr1_outpost_tier_4_level', u'sr1_guest_troop_capacity_level',
#        u'sr1_march_size_level', u'sr1_rss_help_bonus_level'],
#       dtype='object', length=161)
